# %% [markdown]
# # Projeto 3 - Ciência dos Dados

# %% [markdown]
# #### Bruno Gomes e Vitória Rocha

# %% [markdown]
# ## 1ª Etapa: escolha das variáveis

# %% [markdown]
# #### Como o PIB e o saneamento básico influenciam na mortalidade infantil?

# %% [markdown]
# Nesse projeto, será analisado como o PIB per capita da população e o percentual desta com acesso ao saneamento básico influenciam a mortalidade de crianças menores de 5 anos de idade no ano de 2007.
#
# Utilizando o site www.gapminder.org como base, foi possível perceber que todas as condições analisadas apresentam uma influência na variável resposta, podendo ser utilizadas como base de pesquisa e estudo.

# %% [markdown]
# #### Variável resposta:
#      Mortalidade infantil
#
# #### Variáveis explicativas:
#      PIB per capita e acesso a saneamento básico

# %%
# %matplotlib inline

import os
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import pandas as pd
import numpy as np

import statsmodels.api as sm1 #Usa OLS com X como matriz de planejamento
import statsmodels.formula.api as sm  #Usa OLS como no R

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Usuario\Anaconda3\Scripts

# %%
dados = pd.read_excel("C:\\Users\\Usuario\\Documents\\Insper\\C.D\\Projeto3\\Dados\\Ex_URB.xlsx", index_col=0)

# dados2 = pd.read_excel("C:\\Users\\Usuario\\Documents\\Insper\\C.D\\Projeto3\\Dados\\Completo.xlsx", index_col=0) - Com URB

# %%
dados
# Out:
#                           Sanitation    HDI    GDP  Mortality
# Country
# Afghanistan                       37  0.363   1298      113.2
# Albania                           91  0.729   7977       18.7
# Algeria                           94  0.680  12289       30.7
# Angola                            54  0.471   6453      196.4
# Argentina                         90  0.780  13873       15.8
# Armenia                           90  0.715   6877       21.1
# Australia                        100  0.922  40643        5.4
# Austria                          100  0.870  43418        4.6
# Bahamas                          100  0.770  25412       14.8
# Bangladesh                        53  0.478   2158       59.4
# Barbados                         100  0.791  16099       15.8
# Belarus                           93  0.738  13103        7.9
# Belgium                          100  0.880  41575        4.8
# Belize                            88  0.692   8240       20.6
# ...
